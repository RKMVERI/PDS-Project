# %% [markdown]
# ### Import the python modules

# %%
import numpy as np
import pandas as pd

# %%
# Setting working directory.....................................................................
# %cd C:/Users/Ujjwa/OneDrive/Desktop/BDA/Semester 1/PDS-Project-main/PDS-Project-main/data
# Out:
# C:\Users\Ujjwa\OneDrive\Desktop\BDA\Semester 1\PDS-Project-main\PDS-Project-main\data

# %% [markdown]
# ### Read the data files

# %%
fed1 = pd.read_csv("DEF survey (Responses) - Form Responses 1.csv", header = 0,\
                  names = ['ts','age','sex','work','phy_ff','phy_health','phy_bw', 'phy_ex', 'meal',
              'height','weight','exercise','fruit','veg','cook','spend','income','gymtime',
              'disease','review','rate'])
fed2 = pd.read_csv("DEF2 (Responses) - Form Responses 1.csv", header = 0, \
                  names = ['ts','age','sex','work','phy_ff','phy_health','phy_bw', 'phy_ex', 'meal',
              'height','weight','exercise','fruit','veg','cook','spend','income','gymtime',
              'disease','review','rate'])

# %%
fed1.head()
# Out:
#                     ts  age   sex       work  phy_ff  phy_health  phy_bw  \
# 0  10/19/2021 18:37:01   23  Male  Sedentary       5          10       8
# 1  10/19/2021 20:05:43   21  Male   Moderate       7           8       6
# 2  10/19/2021 20:18:40   23  Male   Moderate       6           9       8
# 3  10/20/2021 11:03:47   21  Male   Moderate       7           6       7
# 4  10/20/2021 11:06:04   23  Male   Moderate       6           9       8
#
#    phy_ex meal  height  ...                                     exercise  \
# 0       1    1     7.0  ...                            Do not interested
# 1       7    4     6.0  ...                                       Others
# 2       8    4     5.6  ...                                       Others
# 3       8    5     6.0  ...             Walk, Run, Outdoor Games, Others
# 4       8    4     5.6  ...  Walk, Weight lifting, Outdoor Games, Others
#
#   fruit  veg  cook  spend  income     gymtime disease             review rate
# ...

# %%
fed2.head()
# Out:
#                     ts   age     sex      work  phy_ff  phy_health  phy_bw  \
# 0  10/20/2021 11:25:38  24.0    Male  Moderate       2           2       3
# 1  10/20/2021 11:26:15  24.0  Female  Moderate       2           3       2
# 2  10/20/2021 11:30:49  20.0    Male  Hardwork       5          10      10
# 3  10/20/2021 11:39:07  20.0    Male  Moderate       3           3       2
# 4  10/20/2021 11:39:28  20.0    Male  Moderate       2           2       4
#
#    phy_ex meal  height  ...                            exercise fruit  veg  \
# 0       3    3    5.70  ...                              Others     0    1
# 1       3    4    5.40  ...  Walk, Dance, Outdoor Games, Others     0    2
# 2      10    4    5.50  ...                           Walk, Run     3    5
# 3       1    5    5.11  ...                Walk, Weight lifting     1    2
# 4       4    3    5.60  ...        Walk, Weight lifting, Others     1    2
#
# ...

# %%
print(fed1.shape, fed2.shape)
# Out:
# (45, 21) (213, 21)

# %% [markdown]
# ### Concate two files

# %%
fed = pd.concat([fed1,fed2])
fed.shape
# Out:
# (471, 21)

# %%
fed.dtypes
# Out:
# age           float64
# sex            object
# work           object
# phy_ff          int64
# phy_health      int64
# phy_bw          int64
# phy_ex          int64
# meal           object
# height        float64
# weight        float64
# exercise       object
# fruit           int64
# veg             int64
# cook            int64
# spend           int64
# income          int64
# gymtime        object
# rate            int64
# ts             object
# disease        object
# review         object
# dtype: object

# %% [markdown]
# ### Drop the unnessery columns

# %%
fed.columns
# Out:
# Index(['age', 'sex', 'work', 'phy_ff', 'phy_health', 'phy_bw', 'phy_ex',
#        'meal', 'height', 'weight', 'exercise', 'fruit', 'veg', 'cook', 'spend',
#        'income', 'gymtime', 'rate', 'ts', 'disease', 'review'],
#       dtype='object')

# %%
fed1=fed.drop(labels=['review', 'ts','disease'],axis=1)

# %% [markdown]
# ### Checking for NA values

# %%
fed1.isnull().values.any()
# Out:
# False

# %%
# We Don't have any NA Values

# %% [markdown]
# ### Descripive statistics of the data

# %%
fed1.describe()
# Out:
#               age      phy_ff  phy_health      phy_bw      phy_ex  \
# count  471.000000  471.000000  471.000000  471.000000  471.000000
# mean    22.278132    4.590234    4.227176    5.203822    5.070064
# std      4.521359    2.622292    2.675616    3.056362    2.991722
# min      0.000000    1.000000    1.000000    1.000000    1.000000
# 25%     20.000000    2.000000    2.000000    3.000000    3.000000
# 50%     22.000000    4.000000    3.000000    4.000000    4.000000
# 75%     24.000000    7.000000    6.000000    8.000000    8.000000
# max     56.000000   10.000000   10.000000   10.000000   10.000000
#
#             height        weight       fruit         veg        cook  \
# count   471.000000  4.710000e+02  471.000000  471.000000  471.000000
# mean     43.191465  4.245436e+12    1.322718    2.384289    1.399151
# std     506.292798  6.508115e+13    1.094422    1.189890    1.277431
# min       4.000000  6.200000e+00    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# ### Saving the dataframe as csv

# %%
 fed1.to_csv('clean-data.csv', index=False)
